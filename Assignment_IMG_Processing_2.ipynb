# %% [markdown]
# <a href="https://colab.research.google.com/github/Ammar-creator-cmd/DataVisualization/blob/main/Assignment_IMG_Processing_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2
import matplotlib.image as mpimg

# %%
img = mpimg.imread("/content/drive/MyDrive/dataset/f4p2.jpg") #imread is for reading and finding the image
plt.imshow(img) #imshow is to show the image
plt.axis("off") #turns off axis labels and ticks for a cleaner display
plt.show()

# %%
def process_image(input_path, output_path):
  image = cv2.imread(input_path)
  if image is None:
    print("Error : Unable to load image.")
    return

grayscale_image = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

cv2.imwrite(output_path, grayscale_image)
print(f"Image processed and saved as {output_path}")


process_image(input_image_path, output_image_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_7193/2710773043.py in <cell line: 0>()
#       5     return
#       6
# ----> 7 grayscale_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
#       8
#       9 cv2.imwrite(output_path, grayscale_image)
#
# NameError: name 'image' is not defined

# %%
input_image_path = '/content/drive/MyDrive/dataset/f4p2.jpg'
output_image_path = '/content/drive/MyDrive/dataset/f4p2_grayscale_img.jpg'
