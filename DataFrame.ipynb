# %% [markdown]
# <a href="https://colab.research.google.com/github/Ammar-creator-cmd/DataVisualization/blob/main/DataFrame.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
student = ["Rick", "Bob", "Mickey", "John"]
print(student)
print(type(student))
# Out:
# ['Rick', 'Bob', 'Mickey', 'John']
# <class 'list'>

# %%
import pandas as pd
student = ["Rick", "Bob", "Mickey", "John"]
s1 = pd.Series(student)

print(s1)
print(type(s1))
# Out:
# 0      Rick
# 1       Bob
# 2    Mickey
# 3      John
# dtype: object
# <class 'pandas.core.series.Series'>

# %%
import pandas as pd
student = [["Rick", "Bob"], ["Mickey", "John"]]
s1 = pd.Series(student)

print(s1)
print(type(s1))
# Out:
# 0       [Rick, Bob]
# 1    [Mickey, John]
# dtype: object
# <class 'pandas.core.series.Series'>

# %%
d1 = {"Column1":["Name", "Grade", "Sex"]}
print(d1)
print(type(d1))
# Out:
# {'Column1': ['Name', 'Grade', 'Sex']}
# <class 'dict'>

# %%
df1 = pd.Series(d1)
print(df1)
print(type(df1))
df1
# Out:
# Column1    [Name, Grade, Sex]
# dtype: object
# <class 'pandas.core.series.Series'>
# Column1    [Name, Grade, Sex]
# dtype: object

# %%
d1 = {"Column1":["Name", "Grade", "Sex"], "Column2":["Rick", 5, "Male"]}
print(d1)
print(type(d1))
# Out:
# {'Column1': ['Name', 'Grade', 'Sex'], 'Column2': ['Rick', 5, 'Male']}
# <class 'dict'>

# %%
df1 = pd.Series(d1)
print(df1)
print()
print(type(df1))
# Out:
# Column1    [Name, Grade, Sex]
# Column2       [Rick, 5, Male]
# dtype: object
#
# <class 'pandas.core.series.Series'>

# %%
df1
student = [["Rick", 5, "Male"]]

#creating panda data frame
df = pd.DataFrame(student)

df
# Out:
#       0  1     2
# 0  Rick  5  Male
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['index']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'index'}, axis=1)
#               .sort_values('index', ascending=True))
#   xs = counted['index']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_10.sort_values('index', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('count()')
# from matplotlib import pyplot as plt
# ...

# %%
student = [['Rick', 5, "Male"],
['Bob', 7, "Male"],
['Chloe', 8, "Female"],
['John', 3, "Male"]]

# Creating a Pandas DataFrame
df = pd.DataFrame(student, columns = ["Name", "Grade", "Sex"])

# Printing the type of DataFrame
#print(type(df))

# Printing the DataFrame
df
# Out:
#     Name  Grade     Sex
# 0   Rick      5    Male
# 1    Bob      7    Male
# 2  Chloe      8  Female
# 3   John      3    Male

# %%
d1 = {"Column1": ["Name", "Grade", "Sex"]}
print(d1)
print(type(d1))

df1 = pd.DataFrame(d1) #keys of dict. becomes labels
print(type(df1))
# Out:
# {'Column1': ['Name', 'Grade', 'Sex']}
# <class 'dict'>
# <class 'pandas.core.frame.DataFrame'>

# %%
d1={'colum1':['Name', 'Grade', 'Sex'],'colum2':['Rick', 5, "Male"],'colum3':['Bob', 7, "Male"], 'colum4': ['Chloe', 8, "Female"],'colum5' : ['John', 3, "Male"]}
print(d1)
print(type(d1))

df1 = pd.DataFrame(d1)
print(df1)
print()
print(type(df1))
df1
# Out:
# {'colum1': ['Name', 'Grade', 'Sex'], 'colum2': ['Rick', 5, 'Male'], 'colum3': ['Bob', 7, 'Male'], 'colum4': ['Chloe', 8, 'Female'], 'colum5': ['John', 3, 'Male']}
# <class 'dict'>
#   colum1 colum2 colum3  colum4 colum5
# 0   Name   Rick    Bob   Chloe   John
# 1  Grade      5      7       8      3
# 2    Sex   Male   Male  Female   Male
#
# <class 'pandas.core.frame.DataFrame'>
#   colum1 colum2 colum3  colum4 colum5
# 0   Name   Rick    Bob   Chloe   John
# 1  Grade      5      7       8      3
# 2    Sex   Male   Male  Female   Male

# %%
d1={'colum1':['Name', 'Grade', 'Sex'],'colum2':['Rick', 5, "Male"],'colum3':['Bob', 7, "Male"], 'colum4': ['Chloe', 8, "Female"],'colum5' : ['John', 3, "Male"]}
print(d1)
print(type(d1))

df1 = pd.DataFrame(d1)
print(df1)
print()
print(type(df1))
df1
# Out:
# {'colum1': ['Name', 'Grade', 'Sex'], 'colum2': ['Rick', 5, 'Male'], 'colum3': ['Bob', 7, 'Male'], 'colum4': ['Chloe', 8, 'Female'], 'colum5': ['John', 3, 'Male']}
# <class 'dict'>
#   colum1 colum2 colum3  colum4 colum5
# 0   Name   Rick    Bob   Chloe   John
# 1  Grade      5      7       8      3
# 2    Sex   Male   Male  Female   Male
#
# <class 'pandas.core.frame.DataFrame'>
#   colum1 colum2 colum3  colum4 colum5
# 0   Name   Rick    Bob   Chloe   John
# 1  Grade      5      7       8      3
# 2    Sex   Male   Male  Female   Male

# %%
d1={'Name':['Rick','Bob','Micky','John'], 'Grade':[5,7,8,3], 'Sex':["Male","Male","Female","Male"]}
d1 = pd.DataFrame(d1)
print(d1)
print(type(d1))
# Out:
#     Name  Grade     Sex
# 0   Rick      5    Male
# 1    Bob      7    Male
# 2  Micky      8  Female
# 3   John      3    Male
# <class 'pandas.core.frame.DataFrame'>

# %%
d1
# Out:
#     Name  Grade     Sex
# 0   Rick      5    Male
# 1    Bob      7    Male
# 2  Micky      8  Female
# 3   John      3    Male
