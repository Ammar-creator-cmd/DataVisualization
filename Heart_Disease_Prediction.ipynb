# %% [markdown]
# <a href="https://colab.research.google.com/github/Ammar-creator-cmd/DataVisualization/blob/main/Heart_Disease_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Data Collection

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
import pandas as pd
import re
google_drive_link = "https://drive.google.com/file/d/1OkVuzkVDGsgU1CdeRqUYQVaSXQ8BuJpr/view?usp=sharing"
file_id = re.search(r"/d/(\w+)/", google_drive_link).group(1)
url = 'https://drive.google.com/uc?id={}'.format(file_id)
data = pd.read_csv(url)

# %%
data.head()
# Out:
#    Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0   70    1                4  130          322             0            2
# 1   67    0                3  115          564             0            2
# 2   57    1                2  124          261             0            0
# 3   64    1                4  128          263             0            0
# 4   74    0                2  120          269             0            2
#
#    Max HR  Exercise angina  ST depression  Slope of ST  \
# 0     109                0            2.4            2
# 1     160                0            1.6            2
# 2     141                0            0.3            1
# 3     105                1            0.2            2
# 4     121                1            0.2            1
#
#    Number of vessels fluro  Thallium Heart Disease
# 0                        3         3      Presence
# 1                        0         7       Absence
# ...

# %% [markdown]
# ### Data Processing

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 270 entries, 0 to 269
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      270 non-null    int64
#  1   Sex                      270 non-null    int64
#  2   Chest pain type          270 non-null    int64
#  3   BP                       270 non-null    int64
#  4   Cholesterol              270 non-null    int64
#  5   FBS over 120             270 non-null    int64
#  6   EKG results              270 non-null    int64
#  7   Max HR                   270 non-null    int64
#  8   Exercise angina          270 non-null    int64
#  9   ST depression            270 non-null    float64
#  10  Slope of ST              270 non-null    int64
#  11  Number of vessels fluro  270 non-null    int64
#  12  Thallium                 270 non-null    int64
#  13  Heart Disease            270 non-null    object
# ...

# %%
data.describe()
# Out:
#               Age         Sex  Chest pain type          BP  Cholesterol  \
# count  270.000000  270.000000       270.000000  270.000000   270.000000
# mean    54.433333    0.677778         3.174074  131.344444   249.659259
# std      9.109067    0.468195         0.950090   17.861608    51.686237
# min     29.000000    0.000000         1.000000   94.000000   126.000000
# 25%     48.000000    0.000000         3.000000  120.000000   213.000000
# 50%     55.000000    1.000000         3.000000  130.000000   245.000000
# 75%     61.000000    1.000000         4.000000  140.000000   280.000000
# max     77.000000    1.000000         4.000000  200.000000   564.000000
#
#        FBS over 120  EKG results      Max HR  Exercise angina  ST depression  \
# count    270.000000   270.000000  270.000000       270.000000      270.00000
# mean       0.148148     1.022222  149.677778         0.329630        1.05000
# std        0.355906     0.997891   23.165717         0.470952        1.14521
# ...

# %%
data["Sex"].value_counts()
# Out:
# Sex
# 1    183
# 0     87
# Name: count, dtype: int64

# %%
data["Heart Disease"].value_counts()
# Out:
# Heart Disease
# Absence     150
# Presence    120
# Name: count, dtype: int64

# %%
#Converting the "Heart Disease" column to integer values
data["Heart Disease"] = data["Heart Disease"].map({"Presence": 1, "Absence": 0})

# %%
data.head()
# Out:
#    Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0   70    1                4  130          322             0            2
# 1   67    0                3  115          564             0            2
# 2   57    1                2  124          261             0            0
# 3   64    1                4  128          263             0            0
# 4   74    0                2  120          269             0            2
#
#    Max HR  Exercise angina  ST depression  Slope of ST  \
# 0     109                0            2.4            2
# 1     160                0            1.6            2
# 2     141                0            0.3            1
# 3     105                1            0.2            2
# 4     121                1            0.2            1
#
#    Number of vessels fluro  Thallium  Heart Disease
# 0                        3         3              1
# 1                        0         7              0
# ...

# %% [markdown]
# ### Data Exploratory and Analysis

# %%
plt.figure(figsize = (4, 5))
sns.countplot(x = "Heart Disease", hue = "Sex", data = data)
plt.xlabel("Heart Disease")
plt.ylabel("Sex")
plt.title("Heart Disease Table")
plt.show()

# %%
plt.figure(figsize = (4, 5))
sns.countplot(data = data, x = "Heart Disease", hue = "Chest pain type")
plt.xlabel("Heart Disease")
plt.ylabel("Chest pain type")
plt.title("Distribution of Heart Disease by Chest pain type")
plt.show()

# %%
plt.figure(figsize = (4, 5))
sns.scatterplot(x = data["Age"], y = data["Sex"], hue = data["Heart Disease"])
plt.title("Scatterplot")
plt.xlabel("Age")
plt.ylabel("Sex")
plt.legend(title = "Heart Disease", loc = "upper right", labels = ["Absence", "Presence"])
plt.show()

# %%
plt.figure(figsize = (6, 10))
sns.scatterplot(x=data['Age'], y=data['ST depression'], hue=data['Heart Disease'])
plt.xlabel("Age")
plt.ylabel("ST Depression")
plt.title("Age vs ST Depression with Heart Disease Scatterplot")
plt.legend(title = "Heart Disease", loc = "upper right", labels = ["Absence", "Presence"])
plt.show()

# %%
plt.figure(figsize = (12, 8))
sns.heatmap(data.corr(), annot = True)
plt.show()

# %% [markdown]
# ### Features and Target

# %%
#Define the Target variable (target)
target = data["Heart Disease"]

#Define the Features variable (features)
features = data.drop("Heart Disease", axis=1)

# %% [markdown]
# ### Data Splitting

# %%
from sklearn.model_selection import train_test_split
features_train, features_test, target_train, target_test = train_test_split(features, target, test_size = 0.3, random_state = 42)

# %% [markdown]
# ### Model Training

# %%
from sklearn.neighbors import KNeighborsClassifier
knn_classifier = KNeighborsClassifier(n_neighbors = 5)

#train the KNN classifier on the training data
knn_classifier.fit(features_train, target_train)
# Out:
# KNeighborsClassifier()

# %% [markdown]
# Support Vector Machine (SVM):

# %%
from sklearn.svm import SVC
svm_classifier = SVC(kernel = "linear")

#train the svm classifier on the training data
svm_classifier.fit(features_train, target_train)
# Out:
# SVC(kernel='linear')

# %% [markdown]
# ### Model Evaluation

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

#make prediction on the test set
knn_predictions = knn_classifier.predict(features_test)

# %%
#calculate accuracy
knn_accuracy = accuracy_score(target_test, knn_predictions)
print(f"KNN Accuracy: {knn_accuracy:.2f}")
# Out:
# KNN Accuracy: 0.64

# %%
#generate a classification report
knn_classification_report = classification_report(target_test, knn_predictions)
print(f"KNN Classification Report : \n{knn_classification_report}")
# Out:
# KNN Classification Report :
#               precision    recall  f1-score   support
#
#            0       0.71      0.69      0.70        49
#            1       0.55      0.56      0.55        32
#
#     accuracy                           0.64        81
#    macro avg       0.63      0.63      0.63        81
# weighted avg       0.64      0.64      0.64        81

# %%
#generate a confusion matrix
knn_confusion_matrix = confusion_matrix(target_test, knn_predictions)
print(f"KNN Confusion Matrix: \n{knn_confusion_matrix}")
# Out:
# KNN Confusion Matrix:
# [[34 15]
#  [14 18]]

# %%
#make prediction using svm classifier
svm_prediction = svm_classifier.predict(features_test)

# %%
#calculate accuracy
svm_accuracy = accuracy_score(target_test, svm_prediction)
print(f"SVM Accuracy: {svm_accuracy:.2f}")
# Out:
# SVM Accuracy: 0.83

# %%
#generate a classification report
svm_classification_report = classification_report(target_test, svm_prediction)
print(f"SVM Classification Report : \n{svm_classification_report}")
# Out:
# SVM Classification Report :
#               precision    recall  f1-score   support
#
#            0       0.82      0.92      0.87        49
#            1       0.85      0.69      0.76        32
#
#     accuracy                           0.83        81
#    macro avg       0.83      0.80      0.81        81
# weighted avg       0.83      0.83      0.82        81

# %%
#generate confusion matrix
svm_confusion_matrix = confusion_matrix(target_test, svm_prediction)
print(f"SVM Confusion Matrix: \n{svm_confusion_matrix}")
# Out:
# SVM Confusion Matrix:
# [[45  4]
#  [10 22]]

# %% [markdown]
# ### Prediction

# %%
# Create a dictionary to map feature names to their corresponding values
single_data_point_dict = {
    'Age': 57,
    'Sex': 1,
    'Chest pain type': 2,
    'BP': 124,
    'Cholesterol': 261,
    'FBS over 120': 0,
    'EKG results': 0,
    'Max HR': 141,
    'Exercise angina': 0,
    'ST depression': 0.3,
    'Slope of ST': 1,
    'Number of vessels fluro': 0,
    'Thallium': 7
}

# %%
#create a Pandas DataFrame from the dictionary
single_data_point_df = pd.DataFrame([single_data_point_dict])

#use the trained SVM model to make a prediction
svm_prediction = svm_classifier.predict(single_data_point_df)
#interpret the predition
if svm_prediction[0] == 1:
  prediction_result = "Presence of Heart Disease"
else:
  prediction_result = "Absence of Heart Disease"
print(f"SVM Prediction: {prediction_result}")
# Out:
# SVM Prediction: Absence of Heart Disease

# %% [markdown]
# ### Assignment 2

# %%
from sklearn.tree import DecisionTreeClassifier

decision3_classifier = DecisionTreeClassifier(random_state = 42)

decision3_classifier.fit(features_train, target_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
#make prediction on the test set
decision3_predictions = decision3_classifier.predict(features_test)

# %%
#calculate accuracy
decision3_accuracy = accuracy_score(target_test, decision3_predictions)
print(f"Decision Tree Accuracy: {decision3_accuracy:.2f}")
# Out:
# Decision Tree Accuracy: 0.72

# %%
#generate a classification report
decision3_classification_report = classification_report(target_test, decision3_predictions)
print(f"Decision Tree Classification Report : \n{decision3_classification_report}")
# Out:
# Decision Tree Classification Report :
#               precision    recall  f1-score   support
#
#            0       0.74      0.82      0.78        49
#            1       0.67      0.56      0.61        32
#
#     accuracy                           0.72        81
#    macro avg       0.70      0.69      0.69        81
# weighted avg       0.71      0.72      0.71        81

# %%
#generate a confusion matrix
decision3_confusion_matrix = confusion_matrix(target_test, decision3_predictions)
print(f"Decision Tree Confusion Matrix: \n{decision3_confusion_matrix}")
# Out:
# Decision Tree Confusion Matrix:
# [[40  9]
#  [14 18]]

# %%
#use the trained Decision Tree model to make a prediction
decision3_prediction = decision3_classifier.predict(single_data_point_df)
#interpret the predition
if decision3_prediction[0] == 1:
  prediction_result = "Presence of Heart Disease"
else:
  prediction_result = "Absence of Heart Disease"
print(f"Decision Tree Prediction: {prediction_result}")
# Out:
# Decision Tree Prediction: Presence of Heart Disease
