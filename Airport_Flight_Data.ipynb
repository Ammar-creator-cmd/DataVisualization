# %% [markdown]
# <a href="https://colab.research.google.com/github/Ammar-creator-cmd/DataVisualization/blob/main/Airport_Flight_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
flights_url = 'https://drive.google.com/uc?id=13XxxA7DMXH64KtdHeqWH4W6_lOVrcmOV'
airports_url = 'https://drive.google.com/uc?id=1LhmE6VUZoArDDk4bYn8AEU3dnqomCGqR'

# %%
flights_data = pd.read_csv(flights_url)
airports_data = pd.read_csv(airports_url)

# %%
flights_data.head()
# Out:
#    DayofMonth  DayOfWeek Carrier  OriginAirportID  DestAirportID  DepDelay  \
# 0          19          5      DL            11433          13303        -3
# 1          19          5      DL            14869          12478         0
# 2          19          5      DL            14057          14869        -4
# 3          19          5      DL            15016          11433        28
# 4          19          5      DL            11193          12892        -6
#
#    ArrDelay
# 0         1
# 1        -8
# 2       -15
# 3        24
# 4       -11

# %%
airports_data.head()
# Out:
#    airport_id         city state                                 name
# 0       10165  Adak Island    AK                                 Adak
# 1       10299    Anchorage    AK  Ted Stevens Anchorage International
# 2       10304        Aniak    AK                        Aniak Airport
# 3       10754       Barrow    AK      Wiley Post/Will Rogers Memorial
# 4       10551       Bethel    AK                       Bethel Airport

# %%
#scatter plot

plt.figure(figsize = (10, 6))
sns.scatterplot(data = flights_data, x = "DepDelay", y = "ArrDelay")
plt.title("Departyre Delay vs Arrival Delay")
plt.xlabel("Departure Delay (mins.)")
plt.ylabel("Arrival Delay (mins.)")
plt.show()

# %%
airport_flights = flights_data.merge(airports_data, right_on='airport_id', left_on='OriginAirportID', how='inner')

# %%
airport_flights.head()
# Out:
#    DayofMonth  DayOfWeek Carrier  OriginAirportID  DestAirportID  DepDelay  \
# 0          19          5      DL            11433          13303        -3
# 1          19          5      DL            14869          12478         0
# 2          19          5      DL            14057          14869        -4
# 3          19          5      DL            15016          11433        28
# 4          19          5      DL            11193          12892        -6
#
#    ArrDelay  airport_id            city state  \
# 0         1       11433         Detroit    MI
# 1        -8       14869  Salt Lake City    UT
# 2       -15       14057        Portland    OR
# 3        24       15016       St. Louis    MO
# 4       -11       11193      Cincinnati    OH
#
#                                          name
# 0                  Detroit Metro Wayne County
# 1                Salt Lake City International
# 2                      Portland International
# 3             Lambert-St. Louis International
# 4  Cincinnati/Northern Kentucky International

# %%
airport_flights.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2702218 entries, 0 to 2702217
# Data columns (total 11 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   DayofMonth       int64
#  1   DayOfWeek        int64
#  2   Carrier          object
#  3   OriginAirportID  int64
#  4   DestAirportID    int64
#  5   DepDelay         int64
#  6   ArrDelay         int64
#  7   airport_id       int64
#  8   city             object
#  9   state            object
#  10  name             object
# dtypes: int64(7), object(4)
# memory usage: 226.8+ MB

# %%
plt.figure(figsize =(10, 10))
sns.barplot(data = airport_flights, x = "Carrier",y = "DepDelay", errorbar = None)
plt.title("Average Departure Delay by Carrier")
plt.xlabel("Carrier")
plt.ylabel("Average Departure Delay (mins.)")
plt.show()

# %%
plt.figure(figsize = (10, 10))
sns.countplot(data = airport_flights, x = "state", palette = "Set3")
plt.title("Number of Airports in Each State")
plt.xlabel("States")
plt.ylabel("Number of Airports")
plt.show()
# Out:
# /tmp/ipython-input-1444674159.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data = airport_flights, x = "state", palette = "Set3")
